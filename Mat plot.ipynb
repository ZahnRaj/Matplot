# %%
import matplotlib.pyplot as plt
import numpy as np

parts = ["Heapdhones", "Gaming mouse", "Mousepad", "Keyboard"]
sales = [68, 100, 79, 80]

plt.bar(parts, sales)
plt.title("Computer Peripheral Sales")
plt.xlabel("Peripherals")
plt.ylabel("Sales")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday","Sunday"])
y = np.array([26, 45, 34, 45, 68, 39 , 63 ])

plt.plot(x, y, marker = 'o')
plt.title("EasyPC Store Cavite Sales")
plt.ylabel("Sales")
plt.show()
